# %%
#importing packages
import numpy as np
import pandas as po
import matplotlib.pyplot as plt
import statsmodels.datasets as dt
import statsmodels.api as sm
# Out:
# C:\Users\JAINMOD\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
target_list = po.read_csv('C:/Users/JAINMOD/Desktop/Respiratory/Python Learning/AA_CIU_TARGETS_2017.csv')

# %%
target_list.head()
# Out:
#    NOVID  TIER    ZIP     FNAME    LNAME            CITY STATE SPEC SGRP  \
# 0    636     2  81501   WILLIAM    SCOTT  GRAND JUNCTION    CO    A  ALS
# 1    660     3  31419     JAMES  MEADOWS        SAVANNAH    GA  PUD  PUD
# 2    697     1   3060   WILLIAM  STEPHAN          NASHUA    NH  PUD  PUD
# 3    798     3  30165  TRAMMELL    STARR            ROME    GA  PUD  PUD
# 4    815     3  35233   CORALIE    HAINS      BIRMINGHAM    AL  PDA  ALS
#
#      TERR PROD
# 0  PWXN1C  XIU
# 1  PEXP1G  XOL
# 2  PEXJ1H  XOL
# 3  PEXP1K  XOL
# 4  PEXP1F  XIU

# %%
target_list.sort_values(by = ['TIER', 'SPEC'])
# Out:
#          NOVID  TIER    ZIP        FNAME               LNAME             CITY  \
# 52       10117     1  93010        LEWIS              KANTER        CAMARILLO
# 265      46528     1   8225     NICHOLAS            ROMANOFF       NORTHFIELD
# 331      55546     1  90048       ROBERT             EITCHES      LOS ANGELES
# 395      64823     1  59101     KATHLEEN               DAVIS         BILLINGS
# 462      76553     1  37203          DAN             SANDERS        NASHVILLE
# 530      86887     1  98004     GARRISON               AYARS         BELLEVUE
# 587      97014     1  12601      PRADEEP              SHARMA     POUGHKEEPSIE
# 597      98011     1   6105       PRASAD          SRINIVASAN         HARTFORD
# 637     103396     1   2169       ZUHAYR              HEMADY           QUINCY
# 653     105596     1  21222      HIDAYAT                KHAN        BALTIMORE
# 738     129043     1  28211      CHARLES           HUMPHRIES        CHARLOTTE
# ...

# %%
target_list2 = target_list[target_list('PROD' = 'XOL')]
# Out:
#   File "<ipython-input-7-091498a1a17c>", line 1
#     target_list2 = target_list[target_list('PROD' = 'XOL')]
#                                           ^
# SyntaxError: keyword can't be an expression
